# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./syms.out',header=1,sep='\t')

plt.scatter(df['chi'],df['TMax'])
plt.xscale('log')
plt.xlabel('Scalar Dissipation Rate')
plt.ylabel('Temperature')
plt.ylim(500,2500)
# Out:
# (500.0, 2500.0)
