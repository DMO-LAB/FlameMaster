# %%
import pandas as pd
import subprocess as sp
import numpy as np
import os
import glob
import shutil


#Block 1
df = pd.read_csv('~/Documents/DMO/Spring_2023/Updated_UFPV/CH4_init/output.dout',header=1,sep='\t')
df_sort = np.sort(df['chi_st'])
print(df_sort)
# Out:
# [  2.        2.        2.6       2.6       3.56982   3.57136   4.73834
#    4.78284   6.56203   7.14019   9.04103   9.32186  12.2926   13.3822
#   16.9314   17.301    22.4831   24.0997   30.6856   31.9807   40.8487
#   46.9549   51.9607   54.4547   57.1699   58.5455   61.1779   63.4357
#   63.6331   63.6889   63.8715   65.2315   66.7467   70.5275   70.9929
#   75.9397   77.8329   82.8059   83.0243   84.2759   99.0412  100.918
#  102.666   110.252   114.714   117.354   118.427   137.361   140.825
#  142.041   144.858   153.299   157.599   159.339   173.103   185.398
#  186.79    189.549   200.075   201.888   212.918   214.115   234.355
#  239.829   249.892   256.905   265.251   268.614   272.756   283.12
#  296.872   303.332   324.101   328.695   337.933   338.565   341.181
#  354.155   357.4     377.701   379.868   382.639   385.748   410.791
#  419.541   430.665   430.783   430.79    430.816   430.836   430.841
#  430.846   430.852   430.948   431.101   431.248   431.337   431.451
# ...
